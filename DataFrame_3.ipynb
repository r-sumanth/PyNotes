# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.chdir('/Users/sumanth/Documents/ML_PyNotes/Resource_Notebooks/03-Pandas/')

# %% [markdown]
# ### CSV

# %% [markdown]
# to have the default headers, we can use header=None

# %%
pd.read_csv('example.csv',header=None)
# Out:
#     0   1   2   3
# 0   a   b   c   d
# 1   0   1   2   3
# 2   4   5   6   7
# 3   8   9  10  11
# 4  12  13  14  15

# %%
to set a column as index, we can use index_col=column_number

# %%
pd.read_csv('example.csv',index_col=3)
# Out:
#      a   b   c
# d
# 3    0   1   2
# 7    4   5   6
# 11   8   9  10
# 15  12  13  14

# %%
pd.read_csv('example.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
while exporting to csv, if we need to retain the index column, we can use the parameter index=True

# %%
pd.read_csv('example.csv',header=None,index_col=3)
# Out:
#      0   1   2
# 3
# d    a   b   c
# 3    0   1   2
# 7    4   5   6
# 11   8   9  10
# 15  12  13  14

# %%
pd.read_csv('example.csv',header=None,index_col=3).to_csv('export_example.csv',index=False,header=True)

# %%
pd.read_csv('export_example.csv')
# Out:
#     0   1   2
# 0   a   b   c
# 1   0   1   2
# 2   4   5   6
# 3   8   9  10
# 4  12  13  14

# %%
pd.read_csv('example.csv',header=None,index_col=3).to_csv('export_example.csv',index=True,header=True)

# %%
pd.read_csv('export_example.csv')
# Out:
#     3   0   1   2
# 0   d   a   b   c
# 1   3   0   1   2
# 2   7   4   5   6
# 3  11   8   9  10
# 4  15  12  13  14

# %%
df = pd.read_csv('export_example.csv',index_col=0)

# %%
df
# Out:
#      0   1   2
# 3
# d    a   b   c
# 3    0   1   2
# 7    4   5   6
# 11   8   9  10
# 15  12  13  14

# %%
df = df.reset_index().rename(columns=dict(zip(df.reset_index().columns,df.reset_index().iloc[0,:])))
df = df.drop(index=0,axis=0).reset_index(drop=True)
df
# Out:
#     d   a   b   c
# 0   3   0   1   2
# 1   7   4   5   6
# 2  11   8   9  10
# 3  15  12  13  14

# %%
pd.read_csv('example.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_csv('example.csv').to_csv('export_example.csv',index=False,header=False)

# %%
pd.read_csv('export_example.csv')
# Out:
#     0   1   2   3
# 0   4   5   6   7
# 1   8   9  10  11
# 2  12  13  14  15

# %%
pd.read_csv('example.csv').to_csv('export_example.csv')

# %%
pd.read_csv('export_example.csv')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
pd.read_csv('example.csv').to_csv('export_example.csv',index=False)

# %%
pd.read_csv('export_example.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### HTML

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/India_men%27s_national_field_hockey_team')

# %%
len(tables)
# Out:
# 142

# %%
hockey_olymp_ind = tables[4]
hockey_olymp_ind
# Out:
#    Summer Olympics                                                            \
#               Year                    Host            Round         Position
# 0           1928.0  Amsterdam, Netherlands            Final        Champions
# 1           1932.0        Los Angeles, USA      Group stage        Champions
# 2           1936.0         Berlin, Germany            Final        Champions
# 3           1948.0              London, UK            Final        Champions
# 4           1952.0       Helsinki, Finland            Final        Champions
# 5           1956.0    Melbourne, Australia            Final        Champions
# 6           1960.0             Rome, Italy            Final       Runners-up
# 7           1964.0            Tokyo, Japan            Final        Champions
# 8           1968.0     Mexico City, Mexico      Semi-finals      Third place
# 9           1972.0    Munich, West Germany      Semi-finals      Third place
# ...

# %%
hockey_olymp_ind.columns
# Out:
# MultiIndex([('Summer Olympics',     'Year'),
#             ('Summer Olympics',     'Host'),
#             ('Summer Olympics',    'Round'),
#             ('Summer Olympics', 'Position'),
#             ('Summer Olympics',      'Pld'),
#             ('Summer Olympics',        'W'),
#             ('Summer Olympics',        'D'),
#             ('Summer Olympics',        'L'),
#             ('Summer Olympics',       'GF'),
#             ('Summer Olympics',       'GA')],
#            )

# %%
hockey_olymp_ind = hockey_olymp_ind['Summer Olympics']

# %%
hockey_olymp_ind
# Out:
#       Year                    Host            Round         Position  \
# 0   1928.0  Amsterdam, Netherlands            Final        Champions
# 1   1932.0        Los Angeles, USA      Group stage        Champions
# 2   1936.0         Berlin, Germany            Final        Champions
# 3   1948.0              London, UK            Final        Champions
# 4   1952.0       Helsinki, Finland            Final        Champions
# 5   1956.0    Melbourne, Australia            Final        Champions
# 6   1960.0             Rome, Italy            Final       Runners-up
# 7   1964.0            Tokyo, Japan            Final        Champions
# 8   1968.0     Mexico City, Mexico      Semi-finals      Third place
# 9   1972.0    Munich, West Germany      Semi-finals      Third place
# 10  1976.0        Montreal, Canada      Group stage        7th place
# 11  1980.0            Moscow, USSR            Final        Champions
# 12  1984.0        Los Angeles, USA      Group stage        5th place
# ...

# %%
hockey_olymp_ind.loc[23,'Year'] = ''
hockey_olymp_ind
# Out:
# /var/folders/l8/_b6fjjrx2bd3sc4gf4vqf0vc0000gp/T/ipykernel_17057/946580366.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   hockey_olymp_ind.loc[23,'Year'] = ''
#       Year                    Host            Round         Position  \
# 0   1928.0  Amsterdam, Netherlands            Final        Champions
# 1   1932.0        Los Angeles, USA      Group stage        Champions
# 2   1936.0         Berlin, Germany            Final        Champions
# 3   1948.0              London, UK            Final        Champions
# 4   1952.0       Helsinki, Finland            Final        Champions
# 5   1956.0    Melbourne, Australia            Final        Champions
# 6   1960.0             Rome, Italy            Final       Runners-up
# 7   1964.0            Tokyo, Japan            Final        Champions
# ...

# %%
hockey_olymp_ind['Year'].dtype
# Out:
# dtype('O')

# %%
hockey_olymp_ind['Year'][:-1] = hockey_olymp_ind['Year'][:-1].astype('int')
hockey_olymp_ind
# Out:
# /var/folders/l8/_b6fjjrx2bd3sc4gf4vqf0vc0000gp/T/ipykernel_17057/3415183733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hockey_olymp_ind['Year'][:-1] = hockey_olymp_ind['Year'][:-1].astype('int')
#     Year                    Host            Round         Position  \
# 0   1928  Amsterdam, Netherlands            Final        Champions
# 1   1932        Los Angeles, USA      Group stage        Champions
# 2   1936         Berlin, Germany            Final        Champions
# 3   1948              London, UK            Final        Champions
# 4   1952       Helsinki, Finland            Final        Champions
# 5   1956    Melbourne, Australia            Final        Champions
# 6   1960             Rome, Italy            Final       Runners-up
# ...

# %%
hockey_olymp_ind.set_index('Year',inplace=True)
hockey_olymp_ind
# Out:
#                         Host            Round         Position  \
# Year
# 1928  Amsterdam, Netherlands            Final        Champions
# 1932        Los Angeles, USA      Group stage        Champions
# 1936         Berlin, Germany            Final        Champions
# 1948              London, UK            Final        Champions
# 1952       Helsinki, Finland            Final        Champions
# 1956    Melbourne, Australia            Final        Champions
# 1960             Rome, Italy            Final       Runners-up
# 1964            Tokyo, Japan            Final        Champions
# 1968     Mexico City, Mexico      Semi-finals      Third place
# 1972    Munich, West Germany      Semi-finals      Third place
# 1976        Montreal, Canada      Group stage        7th place
# 1980            Moscow, USSR            Final        Champions
# 1984        Los Angeles, USA      Group stage        5th place
# 1988      Seoul, South Korea      Group stage        6th place
# ...

# %%
hockey_olymp_ind.loc[2008,['Pld','W','D','L','GF','GA']] = [0,0,0,0,0,0]
hockey_olymp_ind
# Out:
# /var/folders/l8/_b6fjjrx2bd3sc4gf4vqf0vc0000gp/T/ipykernel_17057/1977117228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hockey_olymp_ind.loc[2008,['Pld','W','D','L','GF','GA']] = [0,0,0,0,0,0]
#                         Host            Round         Position        Pld  \
# Year
# 1928  Amsterdam, Netherlands            Final        Champions          5
# 1932        Los Angeles, USA      Group stage        Champions          2
# 1936         Berlin, Germany            Final        Champions          5
# 1948              London, UK            Final        Champions          5
# 1952       Helsinki, Finland            Final        Champions          3
# 1956    Melbourne, Australia            Final        Champions          5
# ...

# %%
hockey_olymp_ind.loc[2024,['Pld','W','D','L','GF','GA']] = [8,5,1,2,16,13]
hockey_olymp_ind
# Out:
# /var/folders/l8/_b6fjjrx2bd3sc4gf4vqf0vc0000gp/T/ipykernel_17057/3358944883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hockey_olymp_ind.loc[2024,['Pld','W','D','L','GF','GA']] = [8,5,1,2,16,13]
#                         Host            Round         Position  Pld   W   D  \
# Year
# 1928  Amsterdam, Netherlands            Final        Champions    5   5   0
# 1932        Los Angeles, USA      Group stage        Champions    2   2   0
# 1936         Berlin, Germany            Final        Champions    5   5   0
# 1948              London, UK            Final        Champions    5   5   0
# 1952       Helsinki, Finland            Final        Champions    3   3   0
# 1956    Melbourne, Australia            Final        Champions    5   5   0
# ...

# %%
hockey_olymp_ind.iloc[-1,1] = ''
# Out:
# /var/folders/l8/_b6fjjrx2bd3sc4gf4vqf0vc0000gp/T/ipykernel_17057/976887920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hockey_olymp_ind.iloc[-1,1] = ''

# %%
hockey_olymp_ind
# Out:
#                         Host            Round         Position  Pld   W   D  \
# Year
# 1928  Amsterdam, Netherlands            Final        Champions    5   5   0
# 1932        Los Angeles, USA      Group stage        Champions    2   2   0
# 1936         Berlin, Germany            Final        Champions    5   5   0
# 1948              London, UK            Final        Champions    5   5   0
# 1952       Helsinki, Finland            Final        Champions    3   3   0
# 1956    Melbourne, Australia            Final        Champions    5   5   0
# 1960             Rome, Italy            Final       Runners-up    6   5   0
# 1964            Tokyo, Japan            Final        Champions    9   7   2
# 1968     Mexico City, Mexico      Semi-finals      Third place    9   7   0
# 1972    Munich, West Germany      Semi-finals      Third place    9   6   2
# 1976        Montreal, Canada      Group stage        7th place    8   4   1
# ...

# %%
hockey_olymp_ind[['Pld','W','D','L','GF','GA']] = hockey_olymp_ind[['Pld','W','D','L','GF','GA']].astype('int')
hockey_olymp_ind
# Out:
# /var/folders/l8/_b6fjjrx2bd3sc4gf4vqf0vc0000gp/T/ipykernel_17057/3639087041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hockey_olymp_ind[['Pld','W','D','L','GF','GA']] = hockey_olymp_ind[['Pld','W','D','L','GF','GA']].astype('int')
#                         Host            Round         Position  Pld   W   D  \
# Year
# 1928  Amsterdam, Netherlands            Final        Champions    5   5   0
# 1932        Los Angeles, USA      Group stage        Champions    2   2   0
# 1936         Berlin, Germany            Final        Champions    5   5   0
# 1948              London, UK            Final        Champions    5   5   0
# 1952       Helsinki, Finland            Final        Champions    3   3   0
# ...

# %%
hockey_olymp_ind.loc['',['Pld','W','D','L','GF','GA']] = hockey_olymp_ind.loc[:2024,['Pld','W','D','L','GF','GA']].sum(axis=0)
hockey_olymp_ind
# Out:
#                         Host            Round         Position  Pld   W   D  \
# Year
# 1928  Amsterdam, Netherlands            Final        Champions    5   5   0
# 1932        Los Angeles, USA      Group stage        Champions    2   2   0
# 1936         Berlin, Germany            Final        Champions    5   5   0
# 1948              London, UK            Final        Champions    5   5   0
# 1952       Helsinki, Finland            Final        Champions    3   3   0
# 1956    Melbourne, Australia            Final        Champions    5   5   0
# 1960             Rome, Italy            Final       Runners-up    6   5   0
# 1964            Tokyo, Japan            Final        Champions    9   7   2
# 1968     Mexico City, Mexico      Semi-finals      Third place    9   7   0
# 1972    Munich, West Germany      Semi-finals      Third place    9   6   2
# 1976        Montreal, Canada      Group stage        7th place    8   4   1
# ...

# %%
hockey_olymp_ind.dtypes
# Out:
# Host        object
# Round       object
# Position    object
# Pld          int64
# W            int64
# D            int64
# L            int64
# GF           int64
# GA           int64
# dtype: object

# %%
hockey_olymp_ind.loc[1980,'Position']
# Out:
# 'Champions'

# %%
hockey_olymp_ind.to_html('India_Hockey_Olympics.html')

# %% [markdown]
# ### Excel

# %%
excel = pd.read_excel('my_excel_file.xlsx')
excel
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
sheets = pd.read_excel('my_excel_file.xlsx',sheet_name=None)

# %%
sheets.keys()
# Out:
# dict_keys(['First_Sheet'])

# %%
sheets['First_Sheet']
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.ExcelFile('my_excel_file.xlsx').sheet_names
# Out:
# ['First_Sheet']

# %%
excel.to_excel('export_excel.xlsx',sheet_name='1st Sheet',index=False)

# %% [markdown]
# ### SQL

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
pip install psycopg2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 2.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for psycopg2: filename=psycopg2-2.9.9-cp311-cp311-macosx_11_0_arm64.whl size=132019 sha256=04d75f2814de7cd4b15b3a02b937724779d57bae6006b6a015039737c9c408fc
#   Stored in directory: /Users/sumanth/Library/Caches/pip/wheels/ab/34/b9/78ebef1b3220b4840ee482461e738566c3c9165d2b5c914f51
# Successfully built psycopg2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
eng = create_engine('postgresql+psycopg2://postgres:password@localhost:5432/greencycles')

# %%
stream_movies = pd.read_sql("select * from payment",con=eng)

# %%
stream_movies
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0           16050          269         2          7    1.99
# 1           16051          269         1         98    0.99
# 2           16052          269         2        678    6.99
# 3           16053          269         2        703    0.99
# 4           16054          269         1        750    4.99
# ...           ...          ...       ...        ...     ...
# 16044       32094          245         2      12682    2.99
# 16045       32095          251         1      14107    0.99
# 16046       32096          252         2      13756    4.99
# 16047       32097          263         1      15293    0.99
# 16048       32098          264         2      14243    2.99
#
#                            payment_date
# 0      2020-01-24 22:40:19.996577+01:00
# 1      2020-01-25 16:16:50.996577+01:00
# 2      2020-01-28 22:44:14.996577+01:00
# 3      2020-01-29 01:58:02.996577+01:00
# ...

# %%
actors = pd.read_sql_query("select * from actor",con=eng)
actors
# Out:
#      actor_id first_name     last_name               last_update
# 0           1   PENELOPE       GUINESS 2020-02-15 09:34:33+00:00
# 1           2       NICK      WAHLBERG 2020-02-15 09:34:33+00:00
# 2           3         ED         CHASE 2020-02-15 09:34:33+00:00
# 3           4   JENNIFER         DAVIS 2020-02-15 09:34:33+00:00
# 4           5     JOHNNY  LOLLOBRIGIDA 2020-02-15 09:34:33+00:00
# ..        ...        ...           ...                       ...
# 195       196       BELA        WALKEN 2020-02-15 09:34:33+00:00
# 196       197      REESE          WEST 2020-02-15 09:34:33+00:00
# 197       198       MARY        KEITEL 2020-02-15 09:34:33+00:00
# 198       199      JULIA       FAWCETT 2020-02-15 09:34:33+00:00
# 199       200      THORA        TEMPLE 2020-02-15 09:34:33+00:00
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Pivot tables

# %%
df = pd.read_csv('Sales_Funnel_CRM.csv')
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
pd.pivot(df,index='Company',columns='Product',values='Status').fillna('-')
# Out:
# Product          Analytics GPS Positioning Prediction      Tracking
# Company
#  Google          Presented               -  Presented  Under Review
# ATT                      -               -  Presented  Under Review
# Apple                  Won               -          -             -
# BOBO                  Lost               -          -             -
# CVS Health               -               -          -           Won
# Cisco                 Lost       Presented          -             -
# Exxon Mobile     Presented               -          -             -
# IKEA                   Won               -          -             -
# Microsoft                -               -          -  Under Review
# Salesforce             Won               -          -             -
# Tesla Inc.    Under Review               -  Presented             -
# Walmart               Lost               -          -             -

# %%
df[['Company','Product','Status']].groupby(['Company','Product','Status']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [( Google, Analytics, Presented), ( Google, Prediction, Presented), ( Google, Tracking, Under Review), (ATT, Prediction, Presented), (ATT, Tracking, Under Review), (Apple, Analytics, Won), (BOBO, Analytics, Lost), (CVS Health, Tracking, Won), (Cisco, Analytics, Lost), (Cisco, GPS Positioning, Presented), (Exxon Mobile, Analytics, Presented), (IKEA, Analytics, Won), (Microsoft, Tracking, Under Review), (Salesforce, Analytics, Won), (Tesla Inc., Analytics, Under Review), (Tesla Inc., Prediction, Presented), (Walmart, Analytics, Lost)]

# %%
pd.pivot_table(df[['Company','Product','Licenses','Sale Price']],index='Company',aggfunc='sum')
# Out:
#               Licenses                      Product  Sale Price
# Company
#  Google            600  AnalyticsPredictionTracking     3150000
# ATT                300           TrackingPrediction     1050000
# Apple              300                    Analytics     4550000
# BOBO               150                    Analytics     2450000
# CVS Health         450                     Tracking      490000
# Cisco              600     AnalyticsGPS Positioning     4900000
# Exxon Mobile       150                    Analytics     2100000
# IKEA               300                    Analytics     4550000
# Microsoft          300                     Tracking      350000
# Salesforce         750                    Analytics     7000000
# Tesla Inc.         450          AnalyticsPrediction     3500000
# Walmart            150                    Analytics     2450000

# %%
pd.pivot_table(df,index=['Account Manager','Company'],values=['Sale Price'],columns='Product',aggfunc='sum',fill_value='-')
# Out:
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Company
# Claude Shannon  ATT                   -               -     700000   350000
#                 Apple           4550000               -          -        -
#                 CVS Health            -               -          -   490000
#                 Cisco           4550000          350000          -        -
#                 Exxon Mobile    2100000               -          -        -
#                 Salesforce      7000000               -          -        -
# Edward Thorp     Google         2100000               -     700000   350000
#                 BOBO            2450000               -          -        -
#                 IKEA            4550000               -          -        -
#                 Microsoft             -               -          -   350000
# ...

# %%
df[['Account Manager','Company','Product','Sale Price']].groupby(['Account Manager','Company','Product']).sum()
# Out:
#                                               Sale Price
# Account Manager Company      Product
# Claude Shannon  ATT          Prediction           700000
#                              Tracking             350000
#                 Apple        Analytics           4550000
#                 CVS Health   Tracking             490000
#                 Cisco        Analytics           4550000
#                              GPS Positioning      350000
#                 Exxon Mobile Analytics           2100000
#                 Salesforce   Analytics           7000000
# Edward Thorp     Google      Analytics           2100000
#                              Prediction           700000
#                              Tracking             350000
#                 BOBO         Analytics           2450000
#                 IKEA         Analytics           4550000
#                 Microsoft    Tracking             350000
#                 Tesla Inc.   Analytics           2800000
# ...

# %%
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price','Licenses'],
               columns='Product',aggfunc=['sum','mean'],fill_value='-').T
# Out:
# Account Manager                 Claude Shannon              Edward Thorp  \
# Contact                           Cindy Phoner Emma Gordian    Elon Tusk
#                 Product
# sum  Licenses   Analytics                  450         1050          600
#                 GPS Positioning              -          300            -
#                 Prediction                 150            -          150
#                 Tracking                   150          450            -
#      Sale Price Analytics              6650000     11550000      7350000
#                 GPS Positioning              -       350000            -
#                 Prediction              700000            -       700000
#                 Tracking                350000       490000            -
# mean Licenses   Analytics                225.0        525.0        300.0
#                 GPS Positioning              -        300.0            -
# ...

# %%
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price','Licenses'],
               columns='Product',aggfunc=['sum','mean'],fill_value='-',margins=True).T
# Out:
# Account Manager                 Claude Shannon                 Edward Thorp  \
# Contact                           Cindy Phoner Emma Gordian       Elon Tusk
#                 Product
# sum  Licenses   Analytics                  450         1050             600
#                 GPS Positioning              -          300               -
#                 Prediction                 150            -             150
#                 Tracking                   150          450               -
#                 All                        750         1800             750
#      Sale Price Analytics              6650000     11550000         7350000
#                 GPS Positioning              -       350000               -
#                 Prediction              700000            -          700000
#                 Tracking                350000       490000               -
#                 All                    7700000     12390000         8050000
# ...
